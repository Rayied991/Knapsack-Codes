# %%
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Load the dataset
file_path = '/mnt/d/codes/Datasets/datasetNew.csv'
df = pd.read_csv(file_path)

# Extract resource constraints (last row)
constraint_row = df.iloc[-1, 3:].fillna(0).astype(int).values
df = df.iloc[:-1]

# Extract items and groups
items = []
groups = df['Group'].unique()
num_resources = len(constraint_row)

# Create a list of items with their resource usage and values
for _, row in df.iterrows():
    item = {
        'Group': row['Group'],
        'Item': row['Item'],
        'Value': row['Value'],
        'Resources': row[3:].values.astype(int)
    }
    items.append(item)

# Function to generate an initial solution
def initial_solution(items):
    solution = []
    groups = set(item['Group'] for item in items)
    for group in groups:
        group_items = [item for item in items if item['Group'] == group]
        solution.append(np.random.choice(group_items))
    return solution

# Function to evaluate the solution
def evaluate_solution(solution, constraints):
    group_values = {group: 0 for group in groups}
    total_resources = np.sum([item['Resources'] for item in solution], axis=0)
    valid = np.all(total_resources <= constraints)
    
    for item in solution:
        group_values[item['Group']] += item['Value']
    
    if not valid:
        return -1  # Penalty for invalid solution
    
    return max(group_values.values())  # Return the best value from the groups

# Function to generate a neighboring solution
def neighbor_solution(solution, items):
    new_solution = solution.copy()
    groups = list(set(item['Group'] for item in solution))
    group = np.random.choice(groups)
    group_items = [item for item in items if item['Group'] == group]
    
    if len(group_items) > 1:
        new_item = np.random.choice(group_items)
        idx = next(i for i, item in enumerate(new_solution) if item['Group'] == group)
        new_solution[idx] = new_item

    return new_solution

# Simulated Annealing algorithm implementation
def simulated_annealing(items, constraints, initial_temp=1000, cooling_rate=0.003, max_iterations=1000):
    current_solution = initial_solution(items)
    best_solution = current_solution
    current_value = evaluate_solution(current_solution, constraints)
    best_value = current_value
    temp = initial_temp
    
    for _ in range(max_iterations):
        new_solution = neighbor_solution(current_solution, items)
        new_value = evaluate_solution(new_solution, constraints)
        
        if new_value > current_value or np.random.rand() < np.exp((new_value - current_value) / temp):
            current_solution = new_solution
            current_value = new_value
            if new_value > best_value:
                best_solution = new_solution
                best_value = new_value
        
        temp *= (1 - cooling_rate)
    
    return best_solution, best_value

# Function to select parents for the genetic algorithm
def select_parents(population, scores, num_parents):
    # Ensure scores are valid for sorting
    if not all(isinstance(score, (int, float)) for score in scores):
        raise ValueError("Scores contain non-numeric values.")
    
    sorted_indices = np.argsort(scores)[-num_parents:]
    return [population[i] for i in sorted_indices]

# Function to perform crossover between two parents
def crossover(parent1, parent2):
    crossover_point = np.random.randint(len(parent1))
    return parent1[:crossover_point] + parent2[crossover_point:]

# Function to perform mutation
def mutate(solution, items, mutation_rate):
    if np.random.rand() < mutation_rate:
        group = np.random.choice([item['Group'] for item in solution])
        group_items = [item for item in items if item['Group'] == group]
        if group_items:
            idx = next(i for i, item in enumerate(solution) if item['Group'] == group)
            solution[idx] = np.random.choice(group_items)
    return solution

# Genetic Algorithm implementation
def genetic_algorithm(items, constraints, pop_size=50, num_generations=100, num_parents=10, mutation_rate=0.1):
    population = [initial_solution(items) for _ in range(pop_size)]
    
    for _ in range(num_generations):
        scores = [evaluate_solution(ind, constraints) for ind in population]
        
        # Ensure scores are valid for sorting
        if not all(isinstance(score, (int, float)) for score in scores):
            raise ValueError("Scores contain non-numeric values.")

        parents = select_parents(population, scores, num_parents)
        
        new_population = parents.copy()
        
        while len(new_population) < pop_size:
            parent1, parent2 = np.random.choice(len(parents), 2, replace=False)
            child = crossover(parents[parent1], parents[parent2])
            child = mutate(child, items, mutation_rate)
            new_population.append(child)
        
        population = new_population

    best_individual = max(population, key=lambda ind: evaluate_solution(ind, constraints))
    best_value = evaluate_solution(best_individual, constraints)
    return best_individual, best_value

# Run Simulated Annealing
sa_best_solution, sa_best_value = simulated_annealing(items, constraint_row)

# Run Genetic Algorithm
ga_best_solution, ga_best_value = genetic_algorithm(items, constraint_row)

# Output results
print("Simulated Annealing Results:")
print(f"Best value: {sa_best_value}")

print("\nSimulated Annealing Best Solution:")
for item in sa_best_solution:
    print(f"Group: {item['Group']}, Item: {item['Item']}, Value: {item['Value']}")

print("\nGenetic Algorithm Results:")
print(f"Best value: {ga_best_value}")

print("\nGenetic Algorithm Best Solution:")
for item in ga_best_solution:
    print(f"Group: {item['Group']}, Item: {item['Item']}, Value: {item['Value']}")

print("\nResource Constraints:")
print(constraint_row)
# Out:
# /tmp/ipykernel_24848/3735871357.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   constraint_row = df.iloc[-1, 3:].fillna(0).astype(int).values
# Simulated Annealing Results:
# Best value: 199.0
#
# Simulated Annealing Best Solution:
# Group: Group_100, Item: Item_15, Value: 56.0
# Group: Group_90, Item: Item_2, Value: 27.0
# Group: Group_71, Item: Item_20, Value: 13.0
# Group: Group_7, Item: Item_15, Value: 131.0
# Group: Group_94, Item: Item_7, Value: 187.0
# Group: Group_86, Item: Item_28, Value: 176.0
# Group: Group_10, Item: Item_3, Value: 35.0
# Group: Group_31, Item: Item_3, Value: 52.0
# Group: Group_34, Item: Item_7, Value: 72.0
# Group: Group_97, Item: Item_26, Value: 126.0
# Group: Group_6, Item: Item_28, Value: 139.0
# Group: Group_5, Item: Item_21, Value: 103.0
# Group: Group_12, Item: Item_28, Value: 12.0
# Group: Group_61, Item: Item_7, Value: 130.0
# Group: Group_29, Item: Item_11, Value: 112.0
# Group: Group_1, Item: Item_13, Value: 19.0
# Group: Group_56, Item: Item_8, Value: 60.0
# Group: Group_41, Item: Item_14, Value: 76.0
# Group: Group_15, Item: Item_20, Value: 57.0
# Group: Group_20, Item: Item_24, Value: 106.0
# Group: Group_58, Item: Item_22, Value: 62.0
# Group: Group_44, Item: Item_21, Value: 39.0
# Group: Group_28, Item: Item_2, Value: 64.0
# Group: Group_11, Item: Item_24, Value: 67.0
# Group: Group_66, Item: Item_12, Value: 83.0
# Group: Group_25, Item: Item_25, Value: 78.0
# Group: Group_46, Item: Item_10, Value: 126.0
# Group: Group_59, Item: Item_2, Value: 102.0
# Group: Group_87, Item: Item_28, Value: 42.0
# Group: Group_77, Item: Item_19, Value: 35.0
# Group: Group_64, Item: Item_1, Value: 52.0
# Group: Group_38, Item: Item_24, Value: 14.0
# Group: Group_40, Item: Item_16, Value: 193.0
# Group: Group_60, Item: Item_22, Value: 93.0
# Group: Group_39, Item: Item_29, Value: 124.0
# Group: Group_79, Item: Item_12, Value: 129.0
# Group: Group_37, Item: Item_19, Value: 18.0
# Group: Group_91, Item: Item_24, Value: 65.0
# Group: Group_8, Item: Item_24, Value: 168.0
# Group: Group_18, Item: Item_18, Value: 112.0
# Group: Group_47, Item: Item_10, Value: 71.0
# Group: Group_73, Item: Item_4, Value: 56.0
# Group: Group_35, Item: Item_6, Value: 95.0
# Group: Group_95, Item: Item_22, Value: 117.0
# Group: Group_54, Item: Item_28, Value: 116.0
# Group: Group_63, Item: Item_30, Value: 168.0
# Group: Group_72, Item: Item_24, Value: 66.0
# Group: Group_67, Item: Item_22, Value: 153.0
# Group: Group_96, Item: Item_25, Value: 199.0
# Group: Group_24, Item: Item_19, Value: 89.0
# Group: Group_32, Item: Item_23, Value: 166.0
# Group: Group_76, Item: Item_25, Value: 104.0
# Group: Group_4, Item: Item_9, Value: 174.0
# Group: Group_50, Item: Item_3, Value: 157.0
# Group: Group_22, Item: Item_26, Value: 55.0
# Group: Group_33, Item: Item_17, Value: 112.0
# Group: Group_52, Item: Item_4, Value: 112.0
# Group: Group_70, Item: Item_22, Value: 28.0
# Group: Group_3, Item: Item_6, Value: 30.0
# Group: Group_14, Item: Item_5, Value: 137.0
# Group: Group_43, Item: Item_7, Value: 74.0
# Group: Group_89, Item: Item_23, Value: 154.0
# Group: Group_82, Item: Item_19, Value: 87.0
# Group: Group_69, Item: Item_17, Value: 102.0
# Group: Group_83, Item: Item_8, Value: 33.0
# Group: Group_85, Item: Item_23, Value: 138.0
# Group: Group_80, Item: Item_18, Value: 57.0
# Group: Group_98, Item: Item_26, Value: 159.0
# Group: Group_26, Item: Item_9, Value: 124.0
# Group: Group_13, Item: Item_23, Value: 127.0
# Group: Group_53, Item: Item_21, Value: 86.0
# Group: Group_68, Item: Item_4, Value: 45.0
# Group: Group_93, Item: Item_20, Value: 139.0
# Group: Group_17, Item: Item_30, Value: 106.0
# Group: Group_55, Item: Item_24, Value: 40.0
# Group: Group_48, Item: Item_28, Value: 93.0
# Group: Group_84, Item: Item_9, Value: 187.0
# Group: Group_57, Item: Item_23, Value: 110.0
# Group: Group_92, Item: Item_15, Value: 52.0
# Group: Group_75, Item: Item_8, Value: 132.0
# Group: Group_23, Item: Item_15, Value: 69.0
# Group: Group_2, Item: Item_15, Value: 116.0
# Group: Group_42, Item: Item_14, Value: 115.0
# Group: Group_27, Item: Item_30, Value: 164.0
# Group: Group_78, Item: Item_23, Value: 154.0
# Group: Group_81, Item: Item_23, Value: 32.0
# Group: Group_74, Item: Item_15, Value: 95.0
# Group: Group_51, Item: Item_5, Value: 92.0
# Group: Group_62, Item: Item_3, Value: 128.0
# Group: Group_65, Item: Item_30, Value: 124.0
# Group: Group_21, Item: Item_6, Value: 188.0
# Group: Group_9, Item: Item_22, Value: 23.0
# Group: Group_19, Item: Item_10, Value: 174.0
# Group: Group_88, Item: Item_5, Value: 160.0
# Group: Group_30, Item: Item_22, Value: 64.0
# Group: Group_16, Item: Item_20, Value: 18.0
# Group: Group_49, Item: Item_5, Value: 86.0
# Group: Group_36, Item: Item_6, Value: 159.0
# Group: Group_99, Item: Item_23, Value: 148.0
# Group: Group_45, Item: Item_28, Value: 186.0
#
# Genetic Algorithm Results:
# Best value: 199.0
#
# Genetic Algorithm Best Solution:
# Group: Group_100, Item: Item_15, Value: 56.0
# Group: Group_90, Item: Item_2, Value: 27.0
# Group: Group_71, Item: Item_14, Value: 62.0
# Group: Group_7, Item: Item_13, Value: 182.0
# Group: Group_94, Item: Item_25, Value: 124.0
# Group: Group_86, Item: Item_23, Value: 55.0
# Group: Group_10, Item: Item_6, Value: 132.0
# Group: Group_31, Item: Item_22, Value: 176.0
# Group: Group_34, Item: Item_18, Value: 170.0
# Group: Group_97, Item: Item_26, Value: 126.0
# Group: Group_6, Item: Item_6, Value: 78.0
# Group: Group_5, Item: Item_16, Value: 126.0
# Group: Group_12, Item: Item_12, Value: 190.0
# Group: Group_61, Item: Item_19, Value: 106.0
# Group: Group_29, Item: Item_29, Value: 193.0
# Group: Group_1, Item: Item_27, Value: 141.0
# Group: Group_56, Item: Item_29, Value: 187.0
# Group: Group_41, Item: Item_2, Value: 13.0
# Group: Group_15, Item: Item_17, Value: 108.0
# Group: Group_20, Item: Item_11, Value: 29.0
# Group: Group_58, Item: Item_11, Value: 88.0
# Group: Group_44, Item: Item_21, Value: 39.0
# Group: Group_28, Item: Item_22, Value: 23.0
# Group: Group_11, Item: Item_21, Value: 137.0
# Group: Group_66, Item: Item_21, Value: 184.0
# Group: Group_25, Item: Item_26, Value: 51.0
# Group: Group_46, Item: Item_6, Value: 156.0
# Group: Group_59, Item: Item_19, Value: 156.0
# Group: Group_87, Item: Item_18, Value: 136.0
# Group: Group_77, Item: Item_6, Value: 151.0
# Group: Group_64, Item: Item_13, Value: 59.0
# Group: Group_38, Item: Item_1, Value: 134.0
# Group: Group_40, Item: Item_23, Value: 39.0
# Group: Group_60, Item: Item_6, Value: 37.0
# Group: Group_39, Item: Item_19, Value: 88.0
# Group: Group_79, Item: Item_4, Value: 19.0
# Group: Group_37, Item: Item_14, Value: 98.0
# Group: Group_91, Item: Item_9, Value: 111.0
# Group: Group_8, Item: Item_5, Value: 82.0
# Group: Group_18, Item: Item_13, Value: 30.0
# Group: Group_47, Item: Item_23, Value: 137.0
# Group: Group_73, Item: Item_26, Value: 51.0
# Group: Group_35, Item: Item_18, Value: 18.0
# Group: Group_95, Item: Item_30, Value: 199.0
# Group: Group_54, Item: Item_30, Value: 134.0
# Group: Group_63, Item: Item_29, Value: 125.0
# Group: Group_72, Item: Item_25, Value: 68.0
# Group: Group_67, Item: Item_16, Value: 70.0
# Group: Group_96, Item: Item_27, Value: 14.0
# Group: Group_24, Item: Item_19, Value: 89.0
# Group: Group_32, Item: Item_17, Value: 38.0
# Group: Group_76, Item: Item_25, Value: 104.0
# Group: Group_4, Item: Item_30, Value: 38.0
# Group: Group_50, Item: Item_16, Value: 48.0
# Group: Group_22, Item: Item_27, Value: 179.0
# Group: Group_33, Item: Item_15, Value: 170.0
# Group: Group_52, Item: Item_5, Value: 54.0
# Group: Group_70, Item: Item_10, Value: 128.0
# Group: Group_3, Item: Item_28, Value: 161.0
# Group: Group_14, Item: Item_30, Value: 136.0
# Group: Group_43, Item: Item_2, Value: 32.0
# Group: Group_89, Item: Item_23, Value: 154.0
# Group: Group_82, Item: Item_8, Value: 102.0
# Group: Group_69, Item: Item_16, Value: 73.0
# Group: Group_83, Item: Item_27, Value: 130.0
# Group: Group_85, Item: Item_22, Value: 129.0
# Group: Group_80, Item: Item_5, Value: 47.0
# Group: Group_98, Item: Item_27, Value: 118.0
# Group: Group_26, Item: Item_25, Value: 164.0
# Group: Group_13, Item: Item_29, Value: 22.0
# Group: Group_53, Item: Item_3, Value: 97.0
# Group: Group_68, Item: Item_12, Value: 148.0
# Group: Group_93, Item: Item_13, Value: 119.0
# Group: Group_17, Item: Item_13, Value: 86.0
# Group: Group_55, Item: Item_10, Value: 23.0
# Group: Group_48, Item: Item_4, Value: 139.0
# Group: Group_84, Item: Item_9, Value: 187.0
# Group: Group_57, Item: Item_22, Value: 53.0
# Group: Group_92, Item: Item_24, Value: 76.0
# Group: Group_75, Item: Item_23, Value: 143.0
# Group: Group_23, Item: Item_5, Value: 160.0
# Group: Group_2, Item: Item_1, Value: 44.0
# Group: Group_42, Item: Item_3, Value: 33.0
# Group: Group_27, Item: Item_15, Value: 14.0
# Group: Group_78, Item: Item_24, Value: 50.0
# Group: Group_81, Item: Item_27, Value: 62.0
# Group: Group_74, Item: Item_10, Value: 175.0
# Group: Group_51, Item: Item_8, Value: 186.0
# Group: Group_62, Item: Item_4, Value: 113.0
# Group: Group_65, Item: Item_2, Value: 134.0
# Group: Group_21, Item: Item_29, Value: 33.0
# Group: Group_9, Item: Item_12, Value: 139.0
# Group: Group_19, Item: Item_28, Value: 125.0
# Group: Group_88, Item: Item_25, Value: 198.0
# Group: Group_30, Item: Item_19, Value: 85.0
# Group: Group_16, Item: Item_4, Value: 147.0
# Group: Group_49, Item: Item_15, Value: 61.0
# Group: Group_36, Item: Item_28, Value: 190.0
# Group: Group_99, Item: Item_22, Value: 52.0
# Group: Group_45, Item: Item_9, Value: 178.0
#
# Resource Constraints:
# [6385 7353 5314 4549 5875 6362 6003 6503 5135 5874]
